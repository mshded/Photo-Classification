# %% [markdown]
# # Stage 8 — сравнение подходов (precision-first)
#
# В ноутбуке сравниваются три обязательных сценария:
# 1. `heuristics_only`
# 2. `ml_only`
# 3. `heuristics_plus_ml`
#
# Порог для ML подбирается **только на validation** с приоритетом precision.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
from src.experiments import run_stage8_experiments

# %%
results_df = run_stage8_experiments(
    labels_csv_path='data/labels.csv',
    metrics_output_path='results/metrics.csv',
    model_output_path='models/best_model.pkl',
)
results_df

# %%
metrics_path = Path('results/metrics.csv')
assert metrics_path.exists(), 'results/metrics.csv не найден'
pd.read_csv(metrics_path)

# %% [markdown]
# ## Краткий вывод
#
# - Сравните `precision` в трех экспериментах (главный приоритет проекта).
# - Если `heuristics_plus_ml` снижает `fp` при хорошем `precision`, это предпочтительный вариант для демо.
# - Если `ml_only` дает выше `recall`, но хуже `precision`, явно фиксируйте этот trade-off.
